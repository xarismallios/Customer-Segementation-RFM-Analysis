# %% [markdown]
# # dataset: http://archive.ics.uci.edu/ml/machine-learning-databases/00352/

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

data = pd.read_excel("Online Retail.xlsx")
data.head()
data.describe()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
data= data[pd.notnull(data['CustomerID'])]
data=data.drop_duplicates()
data = data[(data['Quantity']>0)]
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
final=data[['CustomerID','InvoiceDate','InvoiceNo','Quantity','UnitPrice']]

# %%
final['TotalPrice'] = final['Quantity'] * final['UnitPrice']
PRESENT = dt.datetime(2011,12,10)
final['InvoiceDate'] = pd.to_datetime(final['InvoiceDate'])
final
# Out:
# C:\Users\marketing\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\marketing\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         CustomerID         InvoiceDate InvoiceNo  Quantity  UnitPrice  \
# ...

# %%
rfm= final.groupby('CustomerID').agg({'InvoiceDate': lambda date: (PRESENT - date.max()).days,
                                        'InvoiceNo': lambda num: len(num),
                                        'TotalPrice': lambda price: price.sum()})

# %%
rfm.columns=['monetary','frequency','recency']
rfm['recency'] = rfm['recency'].astype(int)

# %%
rfm
# Out:
#             monetary  frequency  recency
# CustomerID
# 12346.0          325          1    77183
# 12347.0            2        182     4310
# 12348.0           75         31     1797
# 12349.0           18         73     1757
# 12350.0          310         17      334
# ...              ...        ...      ...
# 18280.0          277         10      180
# 18281.0          180          7       80
# 18282.0            7         12      178
# 18283.0            3        721     2045
# 18287.0           42         70     1837
#
# [4339 rows x 3 columns]

# %%
rfm['r_quartile'] = pd.qcut(rfm['recency'], 4, ['1','2','3','4'])
rfm['f_quartile'] = pd.qcut(rfm['frequency'], 4, ['4','3','2','1'])
rfm['m_quartile'] = pd.qcut(rfm['monetary'], 4, ['4','3','2','1'])

rfm['RFM_Score'] = rfm.r_quartile.astype(str)+ rfm.f_quartile.astype(str) + rfm.m_quartile.astype(str)
rfm.head()
# Out:
#             monetary  frequency  recency r_quartile f_quartile m_quartile  \
# CustomerID
# 12346.0          325          1    77183          4          4          1
# 12347.0            2        182     4310          4          1          4
# 12348.0           75         31     1797          4          3          2
# 12349.0           18         73     1757          4          2          3
# 12350.0          310         17      334          2          4          1
#
#            RFM_Score
# CustomerID
# 12346.0          441
# 12347.0          414
# 12348.0          432
# 12349.0          423
# 12350.0          241

# %%
rfm[rfm['RFM_Score']=='411'].sort_values('monetary', ascending=False).head()
# Out:
#             monetary  frequency  recency r_quartile f_quartile m_quartile  \
# CustomerID
# 17850.0          372        297     5391          4          1          1
# 12501.0          336        149     2169          4          1          1
# 17406.0          333        111     2184          4          1          1
# 15808.0          306        195     3651          4          1          1
# 13093.0          275        159     7832          4          1          1
#
#            RFM_Score
# CustomerID
# 17850.0          411
# 12501.0          411
# 17406.0          411
# 15808.0          411
# 13093.0          411
